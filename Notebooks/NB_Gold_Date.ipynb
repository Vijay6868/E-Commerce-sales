# %%
# Welcome to your new notebook
# Type here in the cell editor to add code!
from pyspark.sql import *
from pyspark.sql.functions import *
from pyspark.sql.types import   *
# Out:
# StatementMeta(, 47770aec-257a-4c7c-b6c0-8d133b46aa7d, 3, Finished, Available, Finished)

# %%
# %%sql
# CREATE TABLE if NOT EXISTS Ecommere_Lh.gold_date
# (
#     BusinessDate date   ,
#     Business_Year   int ,
#     Business_Month int  ,
#     Business_Quarter   int ,
#     Business_Week int
# )
# USING DELTA
# PARTITIONED BY (Business_Year)
# Out:
# StatementMeta(, 47770aec-257a-4c7c-b6c0-8d133b46aa7d, 20, Finished, Available, Finished)
# <Spark SQL result set with 0 rows and 0 fields>

# %%
start_date = '2015-01-01'
end_date = '2030-12-31'

date_diff = spark.sql("SELECT date_diff('{}','{}')".format(end_date, start_date)).first()[0]
# Out:
# StatementMeta(, 47770aec-257a-4c7c-b6c0-8d133b46aa7d, 21, Finished, Available, Finished)

# %%
date_diff
# Out:
# StatementMeta(, 47770aec-257a-4c7c-b6c0-8d133b46aa7d, 22, Finished, Available, Finished)
# 5843

# %%
ID_Data = spark.range(0, date_diff)
# Out:
# StatementMeta(, 47770aec-257a-4c7c-b6c0-8d133b46aa7d, 23, Finished, Available, Finished)

# %%
date_data = ID_Data.selectExpr("date_add('{}', cast(id as int)) as BusinessDate".format(start_date))
# Out:
# StatementMeta(, 47770aec-257a-4c7c-b6c0-8d133b46aa7d, 31, Finished, Available, Finished)

# %%
date_data.createOrReplaceTempView("ViewDate")
# Out:
# StatementMeta(, 47770aec-257a-4c7c-b6c0-8d133b46aa7d, 32, Finished, Available, Finished)

# %%
# %%sql
# DELETE FROM Ecommere_Lh.gold_date;
#
# INSERT INTO Ecommere_Lh.gold_date
# SELECT * ,
# Year(BusinessDate) as Business_Year ,
# Month(BusinessDate) as Business_Month ,
# Quarter(BusinessDate) as Business_Quarter ,
# weekday(BusinessDate) as Business_Week
# FROM ViewDate
# Out:
# StatementMeta(, 47770aec-257a-4c7c-b6c0-8d133b46aa7d, 34, Finished, Available, Finished)
# <Spark SQL result set with 1 rows and 1 fields>
# <Spark SQL result set with 0 rows and 0 fields>

# %%
# %%sql
# SELECT count(*) FROM Ecommere_Lh.gold_date
# Out:
# StatementMeta(, 47770aec-257a-4c7c-b6c0-8d133b46aa7d, 36, Finished, Available, Finished)
# <Spark SQL result set with 1 rows and 1 fields>
