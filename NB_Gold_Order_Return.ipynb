# %%
# Welcome to your new notebook
# Type here in the cell editor to add code!
from pyspark.sql import *
from pyspark.sql.functions  import *
from pyspark.sql.types import *
# Out:
# StatementMeta(, 41c8eac7-2476-496d-add5-aca57d1e25a2, 3, Finished, Available, Finished)

# %%
# %%sql
# CREATE TABLE IF NOT EXISTS Ecommere_Lh.Gold_Return_Order
# (
#     OrderID string,
#     Return string,
#     Order_Year int,
#     Order_month int,
#     Created_TS timestamp,
#     Modified_TS timestamp
# )
# using DELTA
# PARTITIONED BY(Order_year, Order_Month)
# Out:
# StatementMeta(, 41c8eac7-2476-496d-add5-aca57d1e25a2, 4, Finished, Available, Finished)
# <Spark SQL result set with 0 rows and 0 fields>

# %%
max_date = spark.sql("SELECT coalesce(max('Modified_TS'), '1900-01-01') FROM Ecommere_Lh.Gold_Return_Order").first()[0]
# Out:
# StatementMeta(, 41c8eac7-2476-496d-add5-aca57d1e25a2, 5, Finished, Available, Finished)

# %%
max_date
# Out:
# StatementMeta(, 41c8eac7-2476-496d-add5-aca57d1e25a2, 6, Finished, Available, Finished)
# '1900-01-01'

# %%
df = spark.sql("""SELECT Order_ID ,
Return  ,
Order_Year  ,
Order_Month ,
Created_TS  ,
Modified_TS 
from Ecommere_Lh.bronze_sales where Return = "Yes" and Modified_TS > '{}'""".format(max_date))
# Out:
# StatementMeta(, 41c8eac7-2476-496d-add5-aca57d1e25a2, 11, Finished, Available, Finished)

# %%
df.createOrReplaceTempView("ViewReturn")
# Out:
# StatementMeta(, 41c8eac7-2476-496d-add5-aca57d1e25a2, 12, Finished, Available, Finished)

# %%
# %%sql
# INSERT INTO Ecommere_Lh.Gold_Return_Order
# SELECT * FROM ViewReturn
# Out:
# StatementMeta(, 41c8eac7-2476-496d-add5-aca57d1e25a2, 15, Finished, Available, Finished)
# <Spark SQL result set with 0 rows and 0 fields>

# %%
# %%sql
# SELECT * FROM Gold_Return_Order
# Out:
# StatementMeta(, 41c8eac7-2476-496d-add5-aca57d1e25a2, 17, Finished, Available, Finished)
# <Spark SQL result set with 50 rows and 6 fields>
